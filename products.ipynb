# %%
import os
import requests
import dotenv
import time
import pprint as pp

dotenv.load_dotenv()


def get_bonds(currency: str = "DKK") -> list:
    base_url = f"https://gateway.saxobank.com/sim/openapi/ref/v1/instruments?KeyWords={currency}"  # &AssetType=Bond
    all_data = []
    next_url = base_url

    headers = {"Authorization": f"Bearer {os.getenv('SAXO_BANK_API_TOKEN')}"}

    try:
        while next_url:
            response = requests.get(next_url, headers=headers)
            if response.status_code != 200:
                raise Exception("Failed to get bonds.")

            res = response.json()
            all_data.extend(res.get("Data", []))
            next_url = res.get("__next")

        return all_data
    except Exception as e:
        print("Error:", e)
        return []


def get_instrument_prices(
    uics: str, asset_type: str, account_key: str = "W5XrN6f5W1bmIcddofKdsQ=="
) -> dict:
    base_url = f"https://gateway.saxobank.com/sim/openapi/trade/v1/infoprices/list?AccountKey={account_key}&Uics={uics}&AssetType={asset_type}"
    headers = {"Authorization": f"Bearer {os.getenv('SAXO_BANK_API_TOKEN')}"}
    try:
        response = requests.get(base_url, headers=headers)
        if response.status_code != 200:
            raise Exception(
                f"Failed to get instrument prices. Status code: {response.status_code}, Response: {response.text}"
            )

        return response.json()
    except Exception as e:
        print("Error:", e)
        return {}

# %%
bonds = get_bonds()
print(len(bonds))
for bond in bonds:
    pp.pprint(bond)
# Out:
# 515
# {'AssetType': 'FxSpot',
#  'CurrencyCode': 'JPY',
#  'Description': 'Danish Krone/Japanese Yen',
#  'ExchangeId': 'SBFX',
#  'GroupId': 41186,
#  'Identifier': 4727,
#  'SummaryType': 'Instrument',
#  'Symbol': 'DKKJPY',
#  'TradableAs': ['FxSpot']}
# {'AssetType': 'FxSpot',
#  'CurrencyCode': 'SGD',
#  'Description': 'Danish Krone/Singapore Dollar',
#  'ExchangeId': 'SBFX',
#  'GroupId': 41169,
#  'Identifier': 9443,
#  'SummaryType': 'Instrument',
#  'Symbol': 'DKKSGD',
#  'TradableAs': ['FxSpot']}
# {'AssetType': 'FxSpot',
#  'CurrencyCode': 'PLN',
#  'Description': 'Danish Krone/Polish Zloty',
#  'ExchangeId': 'SBFX',
#  'GroupId': 41095,
#  'Identifier': 21294,
#  'SummaryType': 'Instrument',
#  'Symbol': 'DKKPLN',
#  'TradableAs': ['FxSpot']}
# {'AssetType': 'FxSpot',
#  'CurrencyCode': 'ZAR',
#  'Description': 'Danish Krone/South African Rand',
#  'ExchangeId': 'SBFX',
#  'GroupId': 41171,
#  'Identifier': 9445,
#  'SummaryType': 'Instrument',
#  'Symbol': 'DKKZAR',
#  'TradableAs': ['FxSpot']}
# {'AssetType': 'FxSpot',
#  'CurrencyCode': 'HUF',
#  'Description': 'Danish Krone/Hungarian Forint',
#  'ExchangeId': 'SBFX',
#  'GroupId': 41168,
#  'Identifier': 9442,
#  'SummaryType': 'Instrument',
#  'Symbol': 'DKKHUF',
#  'TradableAs': ['FxSpot']}
# {'AssetType': 'FxSpot',
#  'CurrencyCode': 'CZK',
#  'Description': 'Danish Krone/Czech Koruna',
#  'ExchangeId': 'SBFX',
#  'GroupId': 41167,
#  'Identifier': 9441,
#  'SummaryType': 'Instrument',
#  'Symbol': 'DKKCZK',
#  'TradableAs': ['FxSpot']}
# {'AssetType': 'FxSpot',
#  'CurrencyCode': 'DKK',
#  'Description': 'US Dollar/Danish Krone',
#  'ExchangeId': 'SBFX',
#  'GroupId': 41134,
#  'Identifier': 41,
#  'SummaryType': 'Instrument',
#  'Symbol': 'USDDKK',
#  'TradableAs': ['FxSpot', 'FxForwards', 'FxSwap']}
# {'AssetType': 'FxSpot',
#  'CurrencyCode': 'DKK',
#  'Description': 'Norwegian Krone/Danish Krone',
#  'ExchangeId': 'SBFX',
#  'GroupId': 41196,
#  'Identifier': 2046,
#  'SummaryType': 'Instrument',
#  'Symbol': 'NOKDKK',
#  'TradableAs': ['FxSpot', 'FxForwards', 'FxSwap']}
# {'AssetType': 'FxSpot',
#  'CurrencyCode': 'DKK',
#  'Description': 'Swiss Franc/Danish Krone',
#  'ExchangeId': 'SBFX',
#  'GroupId': 41220,
#  'Identifier': 1311,
#  'SummaryType': 'Instrument',
#  'Symbol': 'CHFDKK',
#  'TradableAs': ['FxSpot', 'FxForwards', 'FxSwap']}
# {'AssetType': 'FxSpot',
#  'CurrencyCode': 'DKK',
#  'Description': 'British Pound/Danish Krone',
#  'ExchangeId': 'SBFX',
#  'GroupId': 41153,
#  'Identifier': 25,
#  'SummaryType': 'Instrument',
#  'Symbol': 'GBPDKK',
#  'TradableAs': ['FxSpot', 'FxForwards', 'FxSwap']}
# {'AssetType': 'FxSpot',
#  'CurrencyCode': 'DKK',
#  'Description': 'Swedish Krone/Danish Krone',
#  'ExchangeId': 'SBFX',
#  'GroupId': 41208,
#  'Identifier': 2047,
#  'SummaryType': 'Instrument',
#  'Symbol': 'SEKDKK',
#  'TradableAs': ['FxSpot', 'FxForwards', 'FxSwap']}
# {'AssetType': 'FxSpot',
#  'CurrencyCode': 'DKK',
#  'Description': 'Australian Dollar/Danish Krone',
#  'ExchangeId': 'SBFX',
#  'GroupId': 41140,
#  'Identifier': 3863,
#  'SummaryType': 'Instrument',
#  'Symbol': 'AUDDKK',
#  'TradableAs': ['FxSpot', 'FxForwards', 'FxSwap']}
# {'AssetType': 'FxSpot',
#  'CurrencyCode': 'DKK',
#  'Description': 'New Zealand Dollar/Danish Krone',
#  'ExchangeId': 'SBFX',
#  'GroupId': 41142,
#  'Identifier': 3864,
#  'SummaryType': 'Instrument',
#  'Symbol': 'NZDDKK',
#  'TradableAs': ['FxSpot', 'FxForwards', 'FxSwap']}
# {'AssetType': 'FxSpot',
#  'CurrencyCode': 'DKK',
#  'Description': 'Euro/Danish Krone',
#  'ExchangeId': 'SBFX',
#  'GroupId': 41203,
#  'Identifier': 16,
#  'SummaryType': 'Instrument',
#  'Symbol': 'EURDKK',
#  'TradableAs': ['FxSpot', 'FxForwards', 'FxSwap']}
# {'AssetType': 'FxSpot',
#  'CurrencyCode': 'DKK',
#  'Description': 'Turkish Lira/Danish Krone',
#  'ExchangeId': 'SBFX',
#  'GroupId': 41029,
#  'Identifier': 21321,
#  'SummaryType': 'Instrument',
#  'Symbol': 'TRYDKK',
#  'TradableAs': ['FxSpot']}
# {'AssetType': 'FxSpot',
#  'CurrencyCode': 'DKK',
#  'Description': 'Japanese Yen/Danish Krone',
#  'ExchangeId': 'SBFX',
#  'GroupId': 41226,
#  'Identifier': 2115,
#  'SummaryType': 'Instrument',
#  'Symbol': 'JPYDKK',
#  'TradableAs': ['FxSpot']}
# {'AssetType': 'FxSpot',
#  'CurrencyCode': 'DKK',
#  'Description': 'Polish Zloty/Danish Krone',
#  'ExchangeId': 'SBFX',
#  'GroupId': 41149,
#  'Identifier': 3934,
#  'SummaryType': 'Instrument',
#  'Symbol': 'PLNDKK',
#  'TradableAs': ['FxSpot']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 4% 01 Oct 2056, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 39032142,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '4NYK01EA56',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 4% 01 Oct 2053, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 32407220,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '4NYK01EDA53',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 4% 01 Oct 2056, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 38225029,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '4NYK01EDA56',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 4% 01 Oct 2056, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 40794915,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '4NYK01E30DA56',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 5% 01 Oct 2053, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 30139365,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '5NYK01E30DA53',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 5% 01 Oct 2053, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 30977839,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '5NYK01EDA53',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 4% 01 Oct 2046, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 37677042,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '4NYK01EA46',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 6% 01 Oct 2053, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 31814359,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '6NYK01EDA53',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 5% 01 Oct 2053, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 31253060,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '5NYK01EA53',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 4% 01 Oct 2053, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 32407223,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '4NYK01EA53',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit A/S 0.5% 1 Oct 2040, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 14602409,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '0,5NYK01EA40',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 3% 01 Oct 2036, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 38008073,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '3NYK01EA36',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 1% 01 Jul 2025, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 29173769,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '1NYK13HJU25DKKRT',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 5% 01 Oct 2056, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 38067934,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '5NYK01E30DA56',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 4% 01 Oct 2053, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 29291481,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '4NYK01E30DA53',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 5% 01 Oct 2043, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 33259536,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '5NYK01EA43',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 3% 01 Oct 2053, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 28486673,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '3NYK01EA53',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 4% 01 Oct 2043, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 30982105,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '4NYK01EA43',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 2.5% 01 Oct 2053, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 27511968,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '25NYK01EDA53',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit A/S 1% 1 Jan 2029, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 14603236,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '1NYK13HJA29DKKRF',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 1% 01 Jul 2026, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 32338155,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '1NYK13Hju26DKKRF',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit A/S 1.0% 1 Jan 2027, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 14601214,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '1NYK13HJA27DKKRF',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 3% 01 Oct 2033, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 30982101,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '3NYK01EA33',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit A/S 0.5% 01 Oct 2043, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 19770344,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '05NYK01EA43',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 1% 01 Jul 2027, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 29937695,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '1NYK13Hju27DKKRF',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 1% 01 Oct 2053, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 32339007,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '1NYK01E30DA53',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 7% 01 Apr 2039, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 1269898,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '7NYKE DA41',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 1% 01 Apr 2029, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 39684714,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '1NYK13GAP29DKKRF',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 2% 01 Jan 2026, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 14596271,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '2NYK13HJADKK26RF',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 1% 01 Oct 2050, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 14234274,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '1NYK01EDA50',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 5% 01 Oct 2056, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 37978058,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '5NYK01EDA56',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 3% 01 Oct 2043, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 30982103,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '3NYK01EA43',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 4% 01 Oct 2038, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 1177484,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '4NYK03D 38',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 3% 01 Oct 2031, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 9087434,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '3NYK01EA_31',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 1% 01 Apr 2026, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 33259497,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '1NYK13GAP26DKKRF',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 6% 01 Oct 2041, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 1184883,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '6NYK01EA 41',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 3.5% 01 Oct 2053, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 32407227,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '35NYK01EA53',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 3% 01 Oct 2053,DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 28649813,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '3NYK01EDA53',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 1% 01 Oct 2040, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 13986464,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '1NYK01EA40',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit A/S 1.0% 1 Jan 2028, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 14601213,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '1NYK13HJA28DKKRF',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 3% 01 Oct 2053, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 30032986,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '3NYK01E30DA53',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit A/S 1.5% 01 Oct 2053,DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 17598747,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '15NYK01EDA53',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 6% 01 Oct 2053, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 31995168,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '6NYK01EA53',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 1% 01 Jul 2028, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 36323470,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '1NYK13HJU28DKKRF',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 1% 1 Oct 2050, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 14231797,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '1NYK01EA50',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 5% 01 Oct 2056, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 36413429,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '5NYK01EA56',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 4% 01 Oct 2041, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 1067235,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '4NYKE A41',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 5% 01 Apr 2038, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 1177487,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '5NYK03D 38',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 4% 01 Oct 2035, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 1177807,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '4NYK03D 35',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 4% 01 Jan 2038, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 1177832,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '4NYK73D OA38',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 3.5% 01 Oct 2044, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 1177845,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '35NYKI A44',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 4% 01 Oct 2026, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 1266556,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '4NYK01EA 26',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 1% 01 Apr 2027, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 1266111,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '1NYK01E A27',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 1.5% 01 Oct 2053, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 28647095,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '15NYK01EA53',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 1% 01 Jan 2032, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 33259501,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '1NYK13HJA32DKKRF',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 1.5% 01 Oct 2050,DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 13387321,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '1,5NYK01EDA50',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 2% 01 Oct 2053,DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 28649811,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '2NYK01EDA53',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 3% 01 Oct 2034, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 1058543,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '3NYKE A34',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 3.5% 01 Oct 2044, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 1066290,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '3,5NYKE A44',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 3% 01 Oct 2046, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 1189457,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '3NYK01E DA47',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 4% 01 Oct 2044, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 1067202,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '4NYKE DA44',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 2% 01 Oct 2034, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 1064932,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '2NYKE A34',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 2.5% 01 Oct 2047, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 1359651,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '25NYK01EA47',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit FRN 01 Jul 2026, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 34775342,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': 'F6NYK32HJU26',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit A/S 1% 01 Oct 2053, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 19716880,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '1NYK01EDA53',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit FRN 01 Oct 2025, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 39729601,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': 'F3NYK32HO25',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 5% 01 Apr 2038, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 881642,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '5NYK73D OA38',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 3% 01 Oct 2044, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 1066294,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '3NYKE A44',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 2% 01 Oct 2053, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 28736952,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '2NYK01EA53',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 0% 01 Oct 2040, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 33259494,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '0NYK01EA40',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 4% 01 Oct 2041, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 1065449,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '4NYK01EDA 41',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 3% 01 Oct 2044, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 1066293,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '3NYKE DA44',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit A/S 1.5% 1 Oct 2040, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 10694000,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '15NYK01EA40',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit A/S 0.5% 01 Oct 2050, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 19716871,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '0,5NYK01EA50',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 0.5% 01 Oct 2053, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 28736936,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '0,5NYK01EDA53',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 2.5% 01 Oct 2047, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 1266118,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '25NYK01EDA47',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 3% 01 Oct 2046, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 1298205,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '3NYK01E A47',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 2% 01 Oct 2050, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 10011292,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '2NYK01EA50',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 2.5% 01 Oct 2050, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 12055965,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '25NYK01EDA50',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit A/S 1% 01 Oct 2043, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 19770346,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '1NYK01EA43',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 6% 01 Oct 2029, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 1268323,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '6NYK3C 29',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 7% 01 Oct 2029, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 1271697,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '7NYK3C 29',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 2% 01 Oct 2047, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 1562191,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '2NYK01EDA47',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit A/S 1% 01 Oct 2053, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 19716872,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '1NYK01EA53',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 2% 01 Oct 2053, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 28648885,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '2NYK01E30DA53',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit FRN 01 Jan 2027, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 37245114,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': 'F6NYK32HJA27',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit FRN 01 Apr 2027, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 40264222,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': 'F3NYK32HAP27',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit A/S 0.5% 1 Oct 2050, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 15107657,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '0,5NYK01EDA50',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 3.5% 01 Oct 2053, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 34493151,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '35NYK01EDA53',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit FRN 01 Jul 2025, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 35378558,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': 'F6NYK32HJU25',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit FRN 01 Jul 2025, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 36946268,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': 'F6NYK32HJULI25',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit FRN 01 Jul 2025, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 14596064,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': 'F6NYK32HJUL25RF',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 4% 01 Oct 2025, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 1176635,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '4NYK02D 25',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit FRN 01 Oct 2025, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 37463797,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': 'F3NYK32HOK25',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit FRN 01 Oct 2025, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 40261269,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': 'F3NYK32HOK25IT',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit FRN 01 Jan 2026, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 33418612,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': 'F6NYK32HJAN26',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit FRN 01 Apr 2026, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 40054692,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': 'F3NYK32HDKKAPR26',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit FRN 01 Jul 2026, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 40275051,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': 'F6NYK32HJUL26',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 7% 01 Oct 2026, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 1271698,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '7NYK 3C 26',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 8% 01 Oct 2026, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 1184927,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '8NYK 3Cs26',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 6% 01 Oct 2026, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 1184925,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '6NYK3C 26',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 3% 01 Oct 2026, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 1268314,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '3NYK01EA 26',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit FRN 01 Apr 2027, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 41618177,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': 'F3NYK32GAP27',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit FRN 01 Jul 2027, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 42192844,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': 'F6NYK32HJUL27',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 8% 01 Jul 2027, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 1271696,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '8NYK3C 29',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 0.728% 01 Jul 2027, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 32337980,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': 'F6NYK32HJU027RF',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit FRN 01 Jul 2027, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 42189424,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': 'F6NYK32HJU27',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit FRN 01 Oct 2027, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 41588664,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': 'F3NYK32OK27',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 0.5% 01 Oct 2027, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 1559830,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '0,5NYK01EA27',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit FRN 01 Oct 2027, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 41590601,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': 'F3NYK32OKT27',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 5.5% 01 Jan 2028, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 1177829,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '5,5VS16.28',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 4% 01 Jan 2028, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 1177485,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '4NYK02D 28',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit FRN 01 Jul 2028, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 11716265,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': 'F6NYK22HJUL28RF',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 5% 01 Oct 2028, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 1177489,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '5NYK02D 28',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 5% 11 Jun 2029, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 11716171,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '5FYN13.29',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 3.5% 11 Jun 2029, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 11716169,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '3,5FYN1330',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 6% 01 Jul 2029, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 11716284,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '6NYKE A31',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 7% 01 Jul 2029, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 1269909,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '7NYKE A31',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 6.5% 01 Jul 2029, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 11716137,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '6,5VS16.29',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 5% 01 Oct 2029, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 1177799,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '5NYK3C 29',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 2% 01 Oct 2029, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 1067234,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '2NYKE A29',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 7% 01 Jan 2030, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 11716158,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '7JLK 15.30',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 5% 01 Apr 2030, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 1269892,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '5NYK01EA 31',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 6% 01 Jul 2030, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 11716156,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '6JLK 15.30',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 6% 01 Jul 2030, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 11716151,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '6 KBH13.30',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 5% 14 Mar 2028, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 34431024,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '5JLK 15.30',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 4.5% 01 Jul 2030, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 33259433,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '4,5JLK1530',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 0.5% 01 Oct 2030, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 10697545,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '0,5NYK01EA30',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit A/S 0.0% 1 Oct 2030, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 14602543,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '0NYK01EA30',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit -0.5% 01 Oct 2030, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 32303231,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '-05NYK01EA30',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 4% 11 Dec 2030, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 34495447,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '4FYN 13.30',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 8% 01 Jan 2031, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 1271811,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '8NYK 03A.32',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 2% 01 Jul 2031, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 12055971,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '2NYK01E A32',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 4% 01 Oct 2031, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 1268320,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '4NYK01EA 31',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 4% 01 Apr 2032, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 1269900,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '4NYKE A34',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 7% 11 Jun 2032, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 11845246,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '7FYN13.32',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 7% 01 Jul 2032, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 1271686,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '7NYK 03A.32',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 1% 01 Oct 2032, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 1559829,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '1NYK01EA32',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 5% 01 Oct 2032, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 1269914,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '5NYK 03A.32',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 6% 01 Oct 2032, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 1269912,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '6NYK 03A.32',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 2% 01 Oct 2033, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 33259519,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '2NYK01EA33',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit -0.5% 01 Oct 2033, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 19797342,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '-05NYK01EA33',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit A/S 0% 01 Oct 2033, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 19716883,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '0NYK01EA33',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 5% 01 Jul 2035, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 1176633,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '5NYK03D 35',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 5% 01 Oct 2035, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 1177810,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '5nyk83D OA35',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit A/S 1% 01 Oct 2035, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 10693994,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '1NYK01EA35',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit A/S 0.5% 1 Oct 2035, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 14601287,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '0,5NYK01EA35',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 0% 01 Oct 2035, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 33259493,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '0NYK01EA35',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 2.5% 01 Oct 2036, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 4015956,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '25NYK01E A37',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 2% 01 Oct 2037, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 2028265,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '2NYK01E A37',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 1.5% 01 Oct 2037, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 1559831,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '1,5NYK01EA37',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit FRN 01 Jan 2038, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 3089525,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': 'NYK 49D3FOA38',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 6% 01 Apr 2038, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 1177491,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '6NYK03D 38',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit FRN 01 Jul 2038, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 12056020,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': 'NYK33D5CF 38',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit 6% 01 Jan 2038, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 1266106,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '6NYK73DOA 38',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit A/S 0.5% 01 Oct 2038, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 57,
#  'Identifier': 19716882,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '0,5NYK01EA38',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Nykredit Realkredit FRN 01 Oct 2038, DKK',
#  'ExchangeId': 'CSE_BONDS',
# ...
#  'Description': 'DLR Kredit A/S 5% 01 Oct 2041, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 50,
#  'Identifier': 1268319,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '5DLR43SDOOA41',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'DLR Kredit A/S 4% 01 Oct 2041, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 50,
#  'Identifier': 1177806,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '4DLR43OAB 41',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'DLR Kredit A/S 6% 01 Oct 2041, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 50,
#  'Identifier': 11716113,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '6DLR43sAB 41',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'DLR Kredit A/S 0.5% 01 Oct 2043, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 50,
#  'Identifier': 42808321,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '0,5 B 2043',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'DLR Kredit A/S 4% 01 Oct 2043, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 50,
#  'Identifier': 33838609,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '4,0 B 2043',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'DLR Kredit A/S 3.5% 01 Jul 2044, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 50,
#  'Identifier': 32302024,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '3,5DLR43SAB 44',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'DLR Kredit A/S 3% 01 Oct 2046, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 50,
#  'Identifier': 12055978,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '3 43OA B 2047',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'DLR Kredit A/S 2.5% 01 Jul 2047, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 50,
#  'Identifier': 32301659,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '2,5 43A B 47',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'DLR Kredit A/S 2% 01 Oct 2047, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 50,
#  'Identifier': 33259472,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '2 B 2047 IO',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'DLR Kredit A/S 2.5% 01 Oct 2047, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 50,
#  'Identifier': 15006120,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '2,5 B 2047 IO',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'DLR Kredit A/S 2% 01 Oct 2047, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 50,
#  'Identifier': 33259461,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '2 43A B 47',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'DLR Kredit A/S 2% 01 Jul 2050, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 50,
#  'Identifier': 33259475,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '2 43 A B 2050',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'DLR Kredit 1.5% 01 Oct 2050, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 50,
#  'Identifier': 16012931,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '1,5 B 2050 IO',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'DLR Kredit A/S 2% 01 Oct 2050, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 50,
#  'Identifier': 28383501,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '2,0 B 2050 IO',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'DLR Kredit A/S 1.5% 01 Oct 2050, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 50,
#  'Identifier': 32472228,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '1,5 43 A B 2050',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'DLR Kredit A/S 1% 01 Oct 2050, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 50,
#  'Identifier': 33259480,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '1 B 2050 IO',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'DLR Kredit A/S 0.5% 01 Jul 2051, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 50,
#  'Identifier': 39232248,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '0,5 OA B 2053',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'DLR Kredit A/S 4% 01 Oct 2053, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 50,
#  'Identifier': 33259521,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '4 B 2053',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'DLR Kredit A/S 3% 01 Oct 2053, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 50,
#  'Identifier': 33259518,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '3,0 B 2053',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'DLR Kredit A/S 2% 01 Oct 2053, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 50,
#  'Identifier': 33259513,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '2,0 OA B 2053',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'DLR Kredit A/S 5% 01 Oct 2053, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 50,
#  'Identifier': 36924824,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '5,0 B 2053',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'DLR Kredit A/S 1% 01 Oct 2053, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 50,
#  'Identifier': 32304283,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '1,0 OA B 2053',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Kingdom of Denmark 0% 15 Nov 2031, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 35266,
#  'Identifier': 21700606,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': 'DENMARK-0-15NOV31',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Kingdom of Denmark 0.5% 15 Nov 2027, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 37631,
#  'Identifier': 8819326,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': 'DANSKE STAT 2027',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Kingdom of Denmark 1.75% 15 Nov 2025, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 38852,
#  'Identifier': 1592298,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': 'Danske Stat 2025',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Totalkredit FRN 01 Jul 2026, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 4568,
#  'Identifier': 11716094,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': 'TK30C4CF 28',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Totalkredit 4% 01 Jul 2035, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 4568,
#  'Identifier': 1265946,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '4tk111C 35',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Totalkredit 3% 01 Jul 2025, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 4568,
#  'Identifier': 1266575,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '3TK111C 25',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Totalkredit 4% 01 Oct 2025, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 4568,
#  'Identifier': 1177512,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '4TK111C 25',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Totalkredit 6% 01 Jul 2026, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 4568,
#  'Identifier': 12055999,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '6TK111C.26',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Totalkredit 6% 01 Jul 2029, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 4568,
#  'Identifier': 12055994,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '6TK111CS29',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Totalkredit 5% 01 Jul 2029, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 4568,
#  'Identifier': 1272773,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '5TK111Cs29',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Totalkredit 7% 01 Jul 2029, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 4568,
#  'Identifier': 9113445,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '7TK111CS29',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Totalkredit 8% 01 Oct 2030, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 4568,
#  'Identifier': 1272767,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '8TK111s.32',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Totalkredit 7% 01 Jul 2031, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 4568,
#  'Identifier': 1272768,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '7TK111s.32',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Totalkredit 5% 01 Jul 2032, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 4568,
#  'Identifier': 12055995,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '5TK111CS32',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Totalkredit 6% 01 Jul 2032, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 4568,
#  'Identifier': 32396356,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '6TK111S.32',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'DLR Kredit A/S 7% 01 Oct 2031, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 4568,
#  'Identifier': 32395985,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '6TK111C 35',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Totalkredit 5% 01 Apr 2035, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 4568,
#  'Identifier': 1177549,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '5TK111C 35',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Totalkredit 5% 01 Apr 2035, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 4568,
#  'Identifier': 1268279,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '5TK41C OA35',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Totalkredit FRN 01 Jan 2037, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 4568,
#  'Identifier': 12056023,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': 'TK40C5CF6 38',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Totalkredit FRN 01 Jan 2038, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 4568,
#  'Identifier': 11716093,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': 'TK30C5 CF38',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Totalkredit FRN 01 Oct 2038, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 4568,
#  'Identifier': 11716092,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': 'TK30C CF38',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Kingdom of Denmark 2.25% 15 Nov 2033, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 31008,
#  'Identifier': 38984232,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': 'DANSKE STAT 2033',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Danmarks Skibskredi FRN 01 Jan 2026, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 52,
#  'Identifier': 11716080,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': 'VAR SK 26',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Danmarks Skibskredit A/S 1.1033% 01 Jan 2028, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 52,
#  'Identifier': 32302444,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': 'VAR SK28C6',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'SPARNORD 3.25% PERP CALL, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 2602,
#  'Identifier': 23242091,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': 'SPARNORD',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Spar Nord Bank 5.131% 07 Jul 2032, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 2602,
#  'Identifier': 39429730,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': 'SPARNORD-FRN-07JUL32',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Gov Faroe Islan 0.125% 02 Jun 2025, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 33236,
#  'Identifier': 28391086,
#  'IssuerCountry': 'FO',
#  'SummaryType': 'Instrument',
#  'Symbol': 'FOROYRA JUN25',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Deutsche Bank 0% 18 Nov 2026, DKK',
#  'ExchangeId': 'LUX_BONDS',
#  'GroupId': 77,
#  'Identifier': 22874607,
#  'IssuerCountry': 'DE',
#  'SummaryType': 'Instrument',
#  'Symbol': 'DEUTSCHEBANK-0-18NOV26',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Kommunekredit 4% 01 Jan 2029, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 38903,
#  'Identifier': 1271691,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '4 KOM54A29',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Kingdom of Denmark 0.5% 15 Nov 2029, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 35262,
#  'Identifier': 21700603,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': 'DENMARK-0.5-15NOV29',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Denmark 0.1% 15 Nov 2030, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 37235,
#  'Identifier': 11716305,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': 'DGBI',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Kingdom of Denmark 0% 15 Nov 2031, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 32258,
#  'Identifier': 33259516,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': 'DANSKE STAT 2031 GREEN',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Sparekassen Dan FRN 13 Feb 2034, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 1337,
#  'Identifier': 40331334,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': 'SPKVEN-FRN-13FEB34',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Kommunekredit 1.5% 01 Apr 2038, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 32255,
#  'Identifier': 33259476,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '241S A 2040',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Kommunekredit 2.5% 01 Jan 2050, DKK',
#  'ExchangeId': 'CSE_BONDS',
#  'GroupId': 37065,
#  'Identifier': 12055979,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': '2,5KO97IS50',
#  'TradableAs': ['Bond']}
# {'AssetType': 'Bond',
#  'CurrencyCode': 'DKK',
#  'Description': 'Tresu Invt 0% Perp call, DKK',
#  'ExchangeId': 'BONDS',
#  'GroupId': 268,
#  'Identifier': 41498377,
#  'IssuerCountry': 'DK',
#  'SummaryType': 'Instrument',
#  'Symbol': 'TRESU-FRN-PERP',
#  'TradableAs': ['Bond']}

# %%
prices = []
for bond in bonds:
    price = get_instrument_prices(
        uics=str(bond["Identifier"]), asset_type=bond["AssetType"]
    )
    time.sleep(1)  # import time
    if price:
        prices.append(price["Data"][0])
        pp.pprint(price["Data"][0])
# Out:
# {'AssetType': 'FxSpot',
#  'LastUpdated': '2025-04-28T08:37:31.636000Z',
#  'PriceSource': 'SBFX',
#  'Quote': {'Amount': 50000,
#            'Ask': 21.837,
#            'AskSize': 5000000.0,
#            'Bid': 21.827,
#            'BidSize': 5000000.0,
#            'DelayedByMinutes': 0,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 21.832,
#            'PriceSource': 'SBFX',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'Tradable',
#            'PriceTypeBid': 'Tradable'},
#  'Uic': 4727}
# {'AssetType': 'FxSpot',
#  'LastUpdated': '2025-04-28T08:37:34.353000Z',
#  'PriceSource': 'SBFX',
#  'Quote': {'Amount': 50000,
#            'Ask': 0.20013,
#            'AskSize': 6578460.0,
#            'Bid': 0.19963,
#            'BidSize': 6579200.0,
#            'DelayedByMinutes': 0,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 0.19988,
#            'PriceSource': 'SBFX',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'Indicative',
#            'PriceTypeBid': 'Indicative'},
#  'Uic': 9443}
# {'AssetType': 'FxSpot',
#  'LastUpdated': '2025-04-28T08:37:33.616000Z',
#  'PriceSource': 'SBFX',
#  'Quote': {'Amount': 50000,
#            'Ask': 0.5726,
#            'AskSize': 7465040.0,
#            'Bid': 0.5719,
#            'BidSize': 7465390.0,
#            'DelayedByMinutes': 0,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 0.57225,
#            'PriceSource': 'SBFX',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'Tradable',
#            'PriceTypeBid': 'Tradable'},
#  'Uic': 21294}
# {'AssetType': 'FxSpot',
#  'LastUpdated': '2025-04-28T08:37:33.133000Z',
#  'PriceSource': 'SBFX',
#  'Quote': {'Amount': 50000,
#            'Ask': 2.8475,
#            'AskSize': 6578460.0,
#            'Bid': 2.8449,
#            'BidSize': 3289600.0,
#            'DelayedByMinutes': 0,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 2.8462,
#            'PriceSource': 'SBFX',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'Tradable',
#            'PriceTypeBid': 'Tradable'},
#  'Uic': 9445}
# {'AssetType': 'FxSpot',
#  'LastUpdated': '2025-04-28T08:37:30.527000Z',
#  'PriceSource': 'SBFX',
#  'Quote': {'Amount': 50000,
#            'Ask': 54.33,
#            'AskSize': 7465040.0,
#            'Bid': 54.27,
#            'BidSize': 7465390.0,
#            'DelayedByMinutes': 0,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 54.3,
#            'PriceSource': 'SBFX',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'Tradable',
#            'PriceTypeBid': 'Tradable'},
#  'Uic': 9442}
# {'AssetType': 'FxSpot',
#  'LastUpdated': '2025-04-28T08:37:30.527000Z',
#  'PriceSource': 'SBFX',
#  'Quote': {'Amount': 50000,
#            'Ask': 3.348,
#            'AskSize': 7465040.0,
#            'Bid': 3.338,
#            'BidSize': 7465390.0,
#            'DelayedByMinutes': 0,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 3.343,
#            'PriceSource': 'SBFX',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'Tradable',
#            'PriceTypeBid': 'Tradable'},
#  'Uic': 9441}
# {'AssetType': 'FxSpot',
#  'LastUpdated': '2025-04-28T08:37:39.943000Z',
#  'PriceSource': 'SBFX',
#  'Quote': {'Amount': 10000,
#            'Ask': 6.58022,
#            'AskSize': 2200000.0,
#            'Bid': 6.57772,
#            'BidSize': 1100000.0,
#            'DelayedByMinutes': 0,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 6.57897,
#            'PriceSource': 'SBFX',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'Tradable',
#            'PriceTypeBid': 'Tradable'},
#  'Uic': 41}
# {'AssetType': 'FxSpot',
#  'LastUpdated': '2025-04-28T08:37:39.973000Z',
#  'PriceSource': 'SBFX',
#  'Quote': {'Amount': 50000,
#            'Ask': 0.63111,
#            'AskSize': 3100000.0,
#            'Bid': 0.63041,
#            'BidSize': 3100000.0,
#            'DelayedByMinutes': 0,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 0.63076,
#            'PriceSource': 'SBFX',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'Tradable',
#            'PriceTypeBid': 'Tradable'},
#  'Uic': 2046}
# {'AssetType': 'FxSpot',
#  'LastUpdated': '2025-04-28T08:37:42.745000Z',
#  'PriceSource': 'SBFX',
#  'Quote': {'Amount': 10000,
#            'Ask': 7.9176,
#            'AskSize': 2000000.0,
#            'Bid': 7.9158,
#            'BidSize': 2000000.0,
#            'DelayedByMinutes': 0,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 7.9167,
#            'PriceSource': 'SBFX',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'Tradable',
#            'PriceTypeBid': 'Tradable'},
#  'Uic': 1311}
# {'AssetType': 'FxSpot',
#  'LastUpdated': '2025-04-28T08:37:42.470000Z',
#  'PriceSource': 'SBFX',
#  'Quote': {'Amount': 10000,
#            'Ask': 8.7656,
#            'AskSize': 2000000.0,
#            'Bid': 8.76,
#            'BidSize': 2000000.0,
#            'DelayedByMinutes': 0,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 8.7628,
#            'PriceSource': 'SBFX',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'Tradable',
#            'PriceTypeBid': 'Tradable'},
#  'Uic': 25}
# {'AssetType': 'FxSpot',
#  'LastUpdated': '2025-04-28T08:37:28.007000Z',
#  'PriceSource': 'SBFX',
#  'Quote': {'Amount': 50000,
#            'Ask': 0.6786,
#            'AskSize': 2900000.0,
#            'Bid': 0.6781,
#            'BidSize': 2900000.0,
#            'DelayedByMinutes': 0,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 0.67835,
#            'PriceSource': 'SBFX',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'Tradable',
#            'PriceTypeBid': 'Tradable'},
#  'Uic': 2047}
# {'AssetType': 'FxSpot',
#  'LastUpdated': '2025-04-28T08:37:42.610000Z',
#  'PriceSource': 'SBFX',
#  'Quote': {'Amount': 10000,
#            'Ask': 4.1969,
#            'AskSize': 2000000.0,
#            'Bid': 4.1933,
#            'BidSize': 2000000.0,
#            'DelayedByMinutes': 0,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 4.1951,
#            'PriceSource': 'SBFX',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'Tradable',
#            'PriceTypeBid': 'Tradable'},
#  'Uic': 3863}
# {'AssetType': 'FxSpot',
#  'LastUpdated': '2025-04-28T08:37:41.507000Z',
#  'PriceSource': 'SBFX',
#  'Quote': {'Amount': 10000,
#            'Ask': 3.9064,
#            'AskSize': 1000000.0,
#            'Bid': 3.9038,
#            'BidSize': 1000000.0,
#            'DelayedByMinutes': 0,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 3.9051,
#            'PriceSource': 'SBFX',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'Tradable',
#            'PriceTypeBid': 'Tradable'},
#  'Uic': 3864}
# {'AssetType': 'FxSpot',
#  'LastUpdated': '2025-04-28T08:37:48.584000Z',
#  'PriceSource': 'SBFX',
#  'Quote': {'Amount': 10000,
#            'Ask': 7.46548,
#            'AskSize': 2000000.0,
#            'Bid': 7.46498,
#            'BidSize': 1100000.0,
#            'DelayedByMinutes': 0,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 7.46523,
#            'PriceSource': 'SBFX',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'Tradable',
#            'PriceTypeBid': 'Tradable'},
#  'Uic': 16}
# {'AssetType': 'FxSpot',
#  'LastUpdated': '2025-04-28T08:37:48.300000Z',
#  'PriceSource': 'SBFX',
#  'Quote': {'Amount': 50000,
#            'Ask': 0.1721,
#            'AskSize': 11600000.0,
#            'Bid': 0.1697,
#            'BidSize': 11600000.0,
#            'DelayedByMinutes': 0,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 0.1709,
#            'PriceSource': 'SBFX',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'Tradable',
#            'PriceTypeBid': 'Tradable'},
#  'Uic': 21321}
# {'AssetType': 'FxSpot',
#  'LastUpdated': '2025-04-28T08:37:48.254000Z',
#  'PriceSource': 'SBFX',
#  'Quote': {'Amount': 500000,
#            'Ask': 0.045815,
#            'AskSize': 287235000.0,
#            'Bid': 0.045789,
#            'BidSize': 143627000.0,
#            'DelayedByMinutes': 0,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 0.045802,
#            'PriceSource': 'SBFX',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'Tradable',
#            'PriceTypeBid': 'Tradable'},
#  'Uic': 2115}
# {'AssetType': 'FxSpot',
#  'LastUpdated': '2025-04-28T08:37:51.306000Z',
#  'PriceSource': 'SBFX',
#  'Quote': {'Amount': 50000,
#            'Ask': 1.7484,
#            'AskSize': 4271030.0,
#            'Bid': 1.7466,
#            'BidSize': 4273050.0,
#            'DelayedByMinutes': 0,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 1.7475,
#            'PriceSource': 'SBFX',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'Tradable',
#            'PriceTypeBid': 'Tradable'},
#  'Uic': 3934}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:21:14.086000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 99.72,
#            'AskSize': 5000000.0,
#            'Bid': 99.52,
#            'BidSize': 5000000.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 99.62,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 39032142}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:22:13.816000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 99.65,
#            'AskSize': 0.0,
#            'Bid': 99.45,
#            'BidSize': 200000.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 99.55,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 32407220}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:18:02.982000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 98.91,
#            'AskSize': 5000000.0,
#            'Bid': 98.71,
#            'BidSize': 5000000.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 98.81,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 38225029}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:22:13.923000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 97.32,
#            'AskSize': 5000000.0,
#            'Bid': 96.85,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 97.09,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 40794915}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T06:44:52.598000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 103.0,
#            'AskSize': 1060222.0,
#            'Bid': 102.35,
#            'BidSize': 340000.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 102.68,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 30139365}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:11:21.618000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 102.75,
#            'AskSize': 420053.0,
#            'Bid': 102.57,
#            'BidSize': 5000000.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 102.66,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 30977839}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:01:09.401000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 100.95,
#            'AskSize': 5000000.0,
#            'Bid': 100.5,
#            'BidSize': 90000.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 100.73,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 37677042}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:21:13.957000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 104.43,
#            'AskSize': 5000000.0,
#            'Bid': 103.68,
#            'BidSize': 5000000.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 104.06,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 31814359}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:11:22.184000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 103.49,
#            'AskSize': 5000000.0,
#            'Bid': 102.89,
#            'BidSize': 5000000.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 103.19,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 31253060}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:22:13.828000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 100.0,
#            'AskSize': 0.0,
#            'Bid': 99.81,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 99.91,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 32407223}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:22:13.847000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 84.53,
#            'AskSize': 5000000.0,
#            'Bid': 83.85,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 84.19,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 14602409}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:22:13.957000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 100.15,
#            'AskSize': 0.0,
#            'Bid': 99.8,
#            'BidSize': 501002.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 99.98,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 38008073}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:22:13.705000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 99.87,
#            'AskSize': 109000.0,
#            'Bid': 99.78,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 99.83,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 29173769}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:22:13.958000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 102.35,
#            'AskSize': 0.0,
#            'Bid': 101.95,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 102.15,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 38067934}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T06:46:56.085000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 99.5,
#            'AskSize': 1651407.0,
#            'Bid': 0.0,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 99.5,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'NoMarket',
#            'PriceTypeBid': 'NoMarket'},
#  'Uic': 29291481}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:22:13.819000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 103.3,
#            'AskSize': 0.0,
#            'Bid': 102.8,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 103.05,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 33259536}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:23:13.517000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 94.8,
#            'AskSize': 0.0,
#            'Bid': 94.2,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 94.5,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 28486673}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:23:13.510000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 101.5,
#            'AskSize': 0.0,
#            'Bid': 101.0,
#            'BidSize': 60000.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 101.25,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 30982105}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:23:13.609000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 88.7,
#            'AskSize': 0.0,
#            'Bid': 88.1,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 88.4,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 27511968}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:23:13.441000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 96.05,
#            'AskSize': 20000000.0,
#            'Bid': 95.86,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 95.96,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 14603236}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:23:13.390000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 99.14,
#            'AskSize': 0.0,
#            'Bid': 99.04,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 99.09,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 32338155}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:23:13.434000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 98.72,
#            'AskSize': 0.0,
#            'Bid': 98.58,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 98.65,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 14601214}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:23:13.503000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 101.3,
#            'AskSize': 0.0,
#            'Bid': 100.5,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 100.9,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 30982101}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:23:13.455000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 83.45,
#            'AskSize': 0.0,
#            'Bid': 82.65,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 83.05,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 19770344}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:23:13.390000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 98.23,
#            'AskSize': 0.0,
#            'Bid': 98.05,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 98.14,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 29937695}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T06:30:00.120000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 63.75,
#            'AskSize': 0.0,
#            'Bid': 0.0,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 63.75,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'NoMarket',
#            'PriceTypeBid': 'NoMarket'},
#  'Uic': 32339007}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:23:13.554000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 0.0,
#            'AskSize': 0.0,
#            'Bid': 109.75,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 109.75,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 1269898}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:23:13.582000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 95.49,
#            'AskSize': 3000000.0,
#            'Bid': 94.89,
#            'BidSize': 3000000.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 95.19,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 39684714}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:23:13.517000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 100.16,
#            'AskSize': 0.0,
#            'Bid': 100.06,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 100.11,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 14596271}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:23:13.429000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 78.7,
#            'AskSize': 5000000.0,
#            'Bid': 78.15,
#            'BidSize': 5000000.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 78.43,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 14234274}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:23:13.634000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 102.9,
#            'AskSize': 0.0,
#            'Bid': 102.54,
#            'BidSize': 5000000.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 102.72,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 37978058}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:23:13.451000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 98.45,
#            'AskSize': 0.0,
#            'Bid': 97.65,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 98.05,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 30982103}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:23:13.475000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 102.55,
#            'AskSize': 0.0,
#            'Bid': 101.55,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 102.05,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 1177484}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:23:13.596000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 101.85,
#            'AskSize': 0.0,
#            'Bid': 100.85,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 101.35,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 9087434}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:23:13.471000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 99.32,
#            'AskSize': 0.0,
#            'Bid': 99.16,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 99.24,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 33259497}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:23:13.544000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 108.25,
#            'AskSize': 0.0,
#            'Bid': 106.25,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 107.25,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 1184883}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:23:13.524000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 97.65,
#            'AskSize': 0.0,
#            'Bid': 97.05,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 97.35,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 32407227}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:23:13.537000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 93.55,
#            'AskSize': 0.0,
#            'Bid': 92.95,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 93.25,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 28649813}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:23:13.663000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 88.4,
#            'AskSize': 0.0,
#            'Bid': 87.6,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 88.0,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 13986464}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:23:13.513000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 97.61,
#            'AskSize': 0.0,
#            'Bid': 97.39,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 97.5,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 14601213}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:18:04.006000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 90.27,
#            'AskSize': 2000000.0,
#            'Bid': 89.57,
#            'BidSize': 2000000.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 89.92,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 30032986}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:23:13.443000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 79.85,
#            'AskSize': 0.0,
#            'Bid': 79.25,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 79.55,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 17598747}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:23:13.525000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 104.7,
#            'AskSize': 0.0,
#            'Bid': 103.7,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 104.2,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 31995168}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:23:13.474000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 96.93,
#            'AskSize': 0.0,
#            'Bid': 96.68,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 96.81,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 36323470}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:23:13.427000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 78.95,
#            'AskSize': 0.0,
#            'Bid': 78.53,
#            'BidSize': 5000000.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 78.74,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 14231797}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:23:13.529000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 103.3,
#            'AskSize': 0.0,
#            'Bid': 102.8,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 103.05,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 36413429}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:23:13.574000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 108.4,
#            'AskSize': 0.0,
#            'Bid': 96.0,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 102.2,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 1067235}
# {'AssetType': 'Bond',
#  'LastUpdated': '0001-01-01T00:00:00.000000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'ErrorCode': 'None',
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'NoAccess',
#            'PriceTypeBid': 'NoAccess'},
#  'Uic': 1177487}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:23:13.495000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 102.55,
#            'AskSize': 0.0,
#            'Bid': 101.55,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 102.05,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 1177807}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:23:13.496000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 102.55,
#            'AskSize': 0.0,
#            'Bid': 101.55,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 102.05,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 1177832}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:23:13.542000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 103.2,
#            'AskSize': 0.0,
#            'Bid': 101.2,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 102.2,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 1177845}
# {'AssetType': 'Bond',
#  'LastUpdated': '0001-01-01T00:00:00.000000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'ErrorCode': 'None',
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'NoAccess',
#            'PriceTypeBid': 'NoAccess'},
#  'Uic': 1266556}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:23:13.550000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 99.85,
#            'AskSize': 0.0,
#            'Bid': 99.05,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 99.45,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 1266111}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:23:13.431000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 82.25,
#            'AskSize': 0.0,
#            'Bid': 81.72,
#            'BidSize': 5000000.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 81.99,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 28647095}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:23:13.646000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 90.94,
#            'AskSize': 0.0,
#            'Bid': 89.54,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 90.24,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 33259501}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:23:13.435000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 81.4,
#            'AskSize': 0.0,
#            'Bid': 80.8,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 81.1,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 13387321}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:23:13.449000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 84.65,
#            'AskSize': 0.0,
#            'Bid': 84.05,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 84.35,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 28649811}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:23:13.541000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 101.7,
#            'AskSize': 0.0,
#            'Bid': 101.1,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 101.4,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 1058543}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:23:13.564000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 102.7,
#            'AskSize': 0.0,
#            'Bid': 100.7,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 101.7,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 1066290}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:23:13.548000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 99.5,
#            'AskSize': 0.0,
#            'Bid': 98.5,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 99.0,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 1189457}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:23:13.571000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 102.45,
#            'AskSize': 0.0,
#            'Bid': 101.45,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 101.95,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 1067202}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:23:13.411000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 98.6,
#            'AskSize': 0.0,
#            'Bid': 97.8,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 98.2,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 1064932}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:23:13.458000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 93.85,
#            'AskSize': 0.0,
#            'Bid': 93.15,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 93.5,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 1359651}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:23:13.434000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 100.53,
#            'AskSize': 0.0,
#            'Bid': 100.33,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 100.43,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 34775342}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:23:13.439000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 75.71,
#            'AskSize': 0.0,
#            'Bid': 73.41,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 74.56,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 19716880}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:23:13.583000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 100.24,
#            'AskSize': 0.0,
#            'Bid': 100.04,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 100.14,
# ...
#  'LastUpdated': '0001-01-01T00:00:00.000000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'ErrorCode': 'None',
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'NoAccess',
#            'PriceTypeBid': 'NoAccess'},
#  'Uic': 36924824}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:32:13.042000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 77.3,
#            'AskSize': 0.0,
#            'Bid': 76.7,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 77.0,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 32304283}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:32:29.100000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 87.48,
#            'AskSize': 5000000.0,
#            'Bid': 87.26,
#            'BidSize': 5000000.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 87.37,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 21700606}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:27:34.029000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 97.43,
#            'AskSize': 5000000.0,
#            'Bid': 97.24,
#            'BidSize': 5000000.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 97.34,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 8819326}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T07:38:22.184000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 100.16,
#            'AskSize': 5000000.0,
#            'Bid': 100.01,
#            'BidSize': 5198214.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 100.09,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 1592298}
# {'AssetType': 'Bond',
#  'LastUpdated': '0001-01-01T00:00:00.000000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'ErrorCode': 'None',
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'NoAccess',
#            'PriceTypeBid': 'NoAccess'},
#  'Uic': 11716094}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:32:12.853000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 102.55,
#            'AskSize': 0.0,
#            'Bid': 101.55,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 102.05,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 1265946}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:32:12.974000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 100.6,
#            'AskSize': 0.0,
#            'Bid': 99.6,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 100.1,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 1266575}
# {'AssetType': 'Bond',
#  'LastUpdated': '0001-01-01T00:00:00.000000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'ErrorCode': 'None',
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'NoAccess',
#            'PriceTypeBid': 'NoAccess'},
#  'Uic': 1177512}
# {'AssetType': 'Bond',
#  'LastUpdated': '0001-01-01T00:00:00.000000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'ErrorCode': 'None',
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'NoAccess',
#            'PriceTypeBid': 'NoAccess'},
#  'Uic': 12055999}
# {'AssetType': 'Bond',
#  'LastUpdated': '0001-01-01T00:00:00.000000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'ErrorCode': 'None',
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'NoAccess',
#            'PriceTypeBid': 'NoAccess'},
#  'Uic': 12055994}
# {'AssetType': 'Bond',
#  'LastUpdated': '0001-01-01T00:00:00.000000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'ErrorCode': 'None',
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'NoAccess',
#            'PriceTypeBid': 'NoAccess'},
#  'Uic': 1272773}
# {'AssetType': 'Bond',
#  'LastUpdated': '0001-01-01T00:00:00.000000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'ErrorCode': 'None',
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'NoAccess',
#            'PriceTypeBid': 'NoAccess'},
#  'Uic': 9113445}
# {'AssetType': 'Bond',
#  'LastUpdated': '0001-01-01T00:00:00.000000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'ErrorCode': 'None',
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'NoAccess',
#            'PriceTypeBid': 'NoAccess'},
#  'Uic': 1272767}
# {'AssetType': 'Bond',
#  'LastUpdated': '0001-01-01T00:00:00.000000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'ErrorCode': 'None',
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'NoAccess',
#            'PriceTypeBid': 'NoAccess'},
#  'Uic': 1272768}
# {'AssetType': 'Bond',
#  'LastUpdated': '0001-01-01T00:00:00.000000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'ErrorCode': 'None',
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'NoAccess',
#            'PriceTypeBid': 'NoAccess'},
#  'Uic': 12055995}
# {'AssetType': 'Bond',
#  'LastUpdated': '0001-01-01T00:00:00.000000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'ErrorCode': 'None',
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'NoAccess',
#            'PriceTypeBid': 'NoAccess'},
#  'Uic': 32396356}
# {'AssetType': 'Bond',
#  'LastUpdated': '0001-01-01T00:00:00.000000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'ErrorCode': 'None',
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'NoAccess',
#            'PriceTypeBid': 'NoAccess'},
#  'Uic': 32395985}
# {'AssetType': 'Bond',
#  'LastUpdated': '0001-01-01T00:00:00.000000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'ErrorCode': 'None',
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'NoAccess',
#            'PriceTypeBid': 'NoAccess'},
#  'Uic': 1177549}
# {'AssetType': 'Bond',
#  'LastUpdated': '0001-01-01T00:00:00.000000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'ErrorCode': 'None',
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'NoAccess',
#            'PriceTypeBid': 'NoAccess'},
#  'Uic': 1268279}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:32:13.079000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 105.4,
#            'AskSize': 0.0,
#            'Bid': 104.4,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 104.9,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 12056023}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:32:13.074000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 105.25,
#            'AskSize': 0.0,
#            'Bid': 104.25,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 104.75,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 11716093}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:32:13.073000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 105.2,
#            'AskSize': 0.0,
#            'Bid': 104.2,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 104.7,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 11716092}
# {'AssetType': 'Bond',
#  'LastUpdated': '0001-01-01T00:00:00.000000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'ErrorCode': 'None',
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'NoAccess',
#            'PriceTypeBid': 'NoAccess'},
#  'Uic': 38984232}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:32:13.073000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 100.63,
#            'AskSize': 0.0,
#            'Bid': 100.33,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 100.48,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 11716080}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:32:13.039000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 101.31,
#            'AskSize': 0.0,
#            'Bid': 100.41,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 100.86,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 32302444}
# {'AssetType': 'Bond',
#  'LastUpdated': '0001-01-01T00:00:00.000000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'ErrorCode': 'None',
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'NoAccess',
#            'PriceTypeBid': 'NoAccess'},
#  'Uic': 23242091}
# {'AssetType': 'Bond',
#  'LastUpdated': '0001-01-01T00:00:00.000000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'ErrorCode': 'None',
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'NoAccess',
#            'PriceTypeBid': 'NoAccess'},
#  'Uic': 39429730}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:33:12.729000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 99.86,
#            'AskSize': 0.0,
#            'Bid': 99.76,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 99.81,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 28391086}
# {'AssetType': 'Bond',
#  'LastUpdated': '0001-01-01T00:00:00.000000Z',
#  'PriceSource': 'LUX_BONDS',
#  'Quote': {'Amount': 0,
#            'ErrorCode': 'None',
#            'PriceSource': 'LUX_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'NoAccess',
#            'PriceTypeBid': 'NoAccess'},
#  'Uic': 22874607}
# {'AssetType': 'Bond',
#  'LastUpdated': '0001-01-01T00:00:00.000000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'ErrorCode': 'None',
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'NoAccess',
#            'PriceTypeBid': 'NoAccess'},
#  'Uic': 1271691}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:32:50.244000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 94.22,
#            'AskSize': 5000000.0,
#            'Bid': 94.03,
#            'BidSize': 5000000.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 94.13,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 21700603}
# {'AssetType': 'Bond',
#  'LastUpdated': '0001-01-01T00:00:00.000000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'ErrorCode': 'None',
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'NoAccess',
#            'PriceTypeBid': 'NoAccess'},
#  'Uic': 11716305}
# {'AssetType': 'Bond',
#  'LastUpdated': '0001-01-01T00:00:00.000000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'ErrorCode': 'None',
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'NoAccess',
#            'PriceTypeBid': 'NoAccess'},
#  'Uic': 33259516}
# {'AssetType': 'Bond',
#  'LastUpdated': '0001-01-01T00:00:00.000000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'ErrorCode': 'None',
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'NoAccess',
#            'PriceTypeBid': 'NoAccess'},
#  'Uic': 40331334}
# {'AssetType': 'Bond',
#  'LastUpdated': '0001-01-01T00:00:00.000000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'ErrorCode': 'None',
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'NoAccess',
#            'PriceTypeBid': 'NoAccess'},
#  'Uic': 33259476}
# {'AssetType': 'Bond',
#  'LastUpdated': '0001-01-01T00:00:00.000000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'ErrorCode': 'None',
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'NoAccess',
#            'PriceTypeBid': 'NoAccess'},
#  'Uic': 12055979}
# {'AssetType': 'Bond',
#  'LastUpdated': '0001-01-01T00:00:00.000000Z',
#  'PriceSource': 'BONDS',
#  'Quote': {'Amount': 0,
#            'ErrorCode': 'None',
#            'PriceSource': 'BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'NoAccess',
#            'PriceTypeBid': 'NoAccess'},
#  'Uic': 41498377}

# %%
for price in prices:
    pp.pprint(price)
# Out:
# {'AssetType': 'FxSpot',
#  'LastUpdated': '2025-04-28T08:37:31.636000Z',
#  'PriceSource': 'SBFX',
#  'Quote': {'Amount': 50000,
#            'Ask': 21.837,
#            'AskSize': 5000000.0,
#            'Bid': 21.827,
#            'BidSize': 5000000.0,
#            'DelayedByMinutes': 0,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 21.832,
#            'PriceSource': 'SBFX',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'Tradable',
#            'PriceTypeBid': 'Tradable'},
#  'Uic': 4727}
# {'AssetType': 'FxSpot',
#  'LastUpdated': '2025-04-28T08:37:34.353000Z',
#  'PriceSource': 'SBFX',
#  'Quote': {'Amount': 50000,
#            'Ask': 0.20013,
#            'AskSize': 6578460.0,
#            'Bid': 0.19963,
#            'BidSize': 6579200.0,
#            'DelayedByMinutes': 0,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 0.19988,
#            'PriceSource': 'SBFX',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'Indicative',
#            'PriceTypeBid': 'Indicative'},
#  'Uic': 9443}
# {'AssetType': 'FxSpot',
#  'LastUpdated': '2025-04-28T08:37:33.616000Z',
#  'PriceSource': 'SBFX',
#  'Quote': {'Amount': 50000,
#            'Ask': 0.5726,
#            'AskSize': 7465040.0,
#            'Bid': 0.5719,
#            'BidSize': 7465390.0,
#            'DelayedByMinutes': 0,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 0.57225,
#            'PriceSource': 'SBFX',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'Tradable',
#            'PriceTypeBid': 'Tradable'},
#  'Uic': 21294}
# {'AssetType': 'FxSpot',
#  'LastUpdated': '2025-04-28T08:37:33.133000Z',
#  'PriceSource': 'SBFX',
#  'Quote': {'Amount': 50000,
#            'Ask': 2.8475,
#            'AskSize': 6578460.0,
#            'Bid': 2.8449,
#            'BidSize': 3289600.0,
#            'DelayedByMinutes': 0,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 2.8462,
#            'PriceSource': 'SBFX',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'Tradable',
#            'PriceTypeBid': 'Tradable'},
#  'Uic': 9445}
# {'AssetType': 'FxSpot',
#  'LastUpdated': '2025-04-28T08:37:30.527000Z',
#  'PriceSource': 'SBFX',
#  'Quote': {'Amount': 50000,
#            'Ask': 54.33,
#            'AskSize': 7465040.0,
#            'Bid': 54.27,
#            'BidSize': 7465390.0,
#            'DelayedByMinutes': 0,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 54.3,
#            'PriceSource': 'SBFX',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'Tradable',
#            'PriceTypeBid': 'Tradable'},
#  'Uic': 9442}
# {'AssetType': 'FxSpot',
#  'LastUpdated': '2025-04-28T08:37:30.527000Z',
#  'PriceSource': 'SBFX',
#  'Quote': {'Amount': 50000,
#            'Ask': 3.348,
#            'AskSize': 7465040.0,
#            'Bid': 3.338,
#            'BidSize': 7465390.0,
#            'DelayedByMinutes': 0,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 3.343,
#            'PriceSource': 'SBFX',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'Tradable',
#            'PriceTypeBid': 'Tradable'},
#  'Uic': 9441}
# {'AssetType': 'FxSpot',
#  'LastUpdated': '2025-04-28T08:37:39.943000Z',
#  'PriceSource': 'SBFX',
#  'Quote': {'Amount': 10000,
#            'Ask': 6.58022,
#            'AskSize': 2200000.0,
#            'Bid': 6.57772,
#            'BidSize': 1100000.0,
#            'DelayedByMinutes': 0,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 6.57897,
#            'PriceSource': 'SBFX',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'Tradable',
#            'PriceTypeBid': 'Tradable'},
#  'Uic': 41}
# {'AssetType': 'FxSpot',
#  'LastUpdated': '2025-04-28T08:37:39.973000Z',
#  'PriceSource': 'SBFX',
#  'Quote': {'Amount': 50000,
#            'Ask': 0.63111,
#            'AskSize': 3100000.0,
#            'Bid': 0.63041,
#            'BidSize': 3100000.0,
#            'DelayedByMinutes': 0,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 0.63076,
#            'PriceSource': 'SBFX',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'Tradable',
#            'PriceTypeBid': 'Tradable'},
#  'Uic': 2046}
# {'AssetType': 'FxSpot',
#  'LastUpdated': '2025-04-28T08:37:42.745000Z',
#  'PriceSource': 'SBFX',
#  'Quote': {'Amount': 10000,
#            'Ask': 7.9176,
#            'AskSize': 2000000.0,
#            'Bid': 7.9158,
#            'BidSize': 2000000.0,
#            'DelayedByMinutes': 0,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 7.9167,
#            'PriceSource': 'SBFX',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'Tradable',
#            'PriceTypeBid': 'Tradable'},
#  'Uic': 1311}
# {'AssetType': 'FxSpot',
#  'LastUpdated': '2025-04-28T08:37:42.470000Z',
#  'PriceSource': 'SBFX',
#  'Quote': {'Amount': 10000,
#            'Ask': 8.7656,
#            'AskSize': 2000000.0,
#            'Bid': 8.76,
#            'BidSize': 2000000.0,
#            'DelayedByMinutes': 0,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 8.7628,
#            'PriceSource': 'SBFX',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'Tradable',
#            'PriceTypeBid': 'Tradable'},
#  'Uic': 25}
# {'AssetType': 'FxSpot',
#  'LastUpdated': '2025-04-28T08:37:28.007000Z',
#  'PriceSource': 'SBFX',
#  'Quote': {'Amount': 50000,
#            'Ask': 0.6786,
#            'AskSize': 2900000.0,
#            'Bid': 0.6781,
#            'BidSize': 2900000.0,
#            'DelayedByMinutes': 0,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 0.67835,
#            'PriceSource': 'SBFX',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'Tradable',
#            'PriceTypeBid': 'Tradable'},
#  'Uic': 2047}
# {'AssetType': 'FxSpot',
#  'LastUpdated': '2025-04-28T08:37:42.610000Z',
#  'PriceSource': 'SBFX',
#  'Quote': {'Amount': 10000,
#            'Ask': 4.1969,
#            'AskSize': 2000000.0,
#            'Bid': 4.1933,
#            'BidSize': 2000000.0,
#            'DelayedByMinutes': 0,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 4.1951,
#            'PriceSource': 'SBFX',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'Tradable',
#            'PriceTypeBid': 'Tradable'},
#  'Uic': 3863}
# {'AssetType': 'FxSpot',
#  'LastUpdated': '2025-04-28T08:37:41.507000Z',
#  'PriceSource': 'SBFX',
#  'Quote': {'Amount': 10000,
#            'Ask': 3.9064,
#            'AskSize': 1000000.0,
#            'Bid': 3.9038,
#            'BidSize': 1000000.0,
#            'DelayedByMinutes': 0,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 3.9051,
#            'PriceSource': 'SBFX',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'Tradable',
#            'PriceTypeBid': 'Tradable'},
#  'Uic': 3864}
# {'AssetType': 'FxSpot',
#  'LastUpdated': '2025-04-28T08:37:48.584000Z',
#  'PriceSource': 'SBFX',
#  'Quote': {'Amount': 10000,
#            'Ask': 7.46548,
#            'AskSize': 2000000.0,
#            'Bid': 7.46498,
#            'BidSize': 1100000.0,
#            'DelayedByMinutes': 0,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 7.46523,
#            'PriceSource': 'SBFX',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'Tradable',
#            'PriceTypeBid': 'Tradable'},
#  'Uic': 16}
# {'AssetType': 'FxSpot',
#  'LastUpdated': '2025-04-28T08:37:48.300000Z',
#  'PriceSource': 'SBFX',
#  'Quote': {'Amount': 50000,
#            'Ask': 0.1721,
#            'AskSize': 11600000.0,
#            'Bid': 0.1697,
#            'BidSize': 11600000.0,
#            'DelayedByMinutes': 0,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 0.1709,
#            'PriceSource': 'SBFX',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'Tradable',
#            'PriceTypeBid': 'Tradable'},
#  'Uic': 21321}
# {'AssetType': 'FxSpot',
#  'LastUpdated': '2025-04-28T08:37:48.254000Z',
#  'PriceSource': 'SBFX',
#  'Quote': {'Amount': 500000,
#            'Ask': 0.045815,
#            'AskSize': 287235000.0,
#            'Bid': 0.045789,
#            'BidSize': 143627000.0,
#            'DelayedByMinutes': 0,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 0.045802,
#            'PriceSource': 'SBFX',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'Tradable',
#            'PriceTypeBid': 'Tradable'},
#  'Uic': 2115}
# {'AssetType': 'FxSpot',
#  'LastUpdated': '2025-04-28T08:37:51.306000Z',
#  'PriceSource': 'SBFX',
#  'Quote': {'Amount': 50000,
#            'Ask': 1.7484,
#            'AskSize': 4271030.0,
#            'Bid': 1.7466,
#            'BidSize': 4273050.0,
#            'DelayedByMinutes': 0,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 1.7475,
#            'PriceSource': 'SBFX',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'Tradable',
#            'PriceTypeBid': 'Tradable'},
#  'Uic': 3934}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:21:14.086000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 99.72,
#            'AskSize': 5000000.0,
#            'Bid': 99.52,
#            'BidSize': 5000000.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 99.62,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 39032142}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:22:13.816000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 99.65,
#            'AskSize': 0.0,
#            'Bid': 99.45,
#            'BidSize': 200000.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 99.55,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 32407220}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:18:02.982000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 98.91,
#            'AskSize': 5000000.0,
#            'Bid': 98.71,
#            'BidSize': 5000000.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 98.81,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 38225029}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:22:13.923000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 97.32,
#            'AskSize': 5000000.0,
#            'Bid': 96.85,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 97.09,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 40794915}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T06:44:52.598000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 103.0,
#            'AskSize': 1060222.0,
#            'Bid': 102.35,
#            'BidSize': 340000.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 102.68,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 30139365}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:11:21.618000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 102.75,
#            'AskSize': 420053.0,
#            'Bid': 102.57,
#            'BidSize': 5000000.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 102.66,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 30977839}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:01:09.401000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 100.95,
#            'AskSize': 5000000.0,
#            'Bid': 100.5,
#            'BidSize': 90000.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 100.73,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 37677042}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:21:13.957000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 104.43,
#            'AskSize': 5000000.0,
#            'Bid': 103.68,
#            'BidSize': 5000000.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 104.06,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 31814359}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:11:22.184000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 103.49,
#            'AskSize': 5000000.0,
#            'Bid': 102.89,
#            'BidSize': 5000000.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 103.19,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 31253060}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:22:13.828000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 100.0,
#            'AskSize': 0.0,
#            'Bid': 99.81,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 99.91,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 32407223}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:22:13.847000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 84.53,
#            'AskSize': 5000000.0,
#            'Bid': 83.85,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 84.19,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 14602409}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:22:13.957000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 100.15,
#            'AskSize': 0.0,
#            'Bid': 99.8,
#            'BidSize': 501002.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 99.98,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 38008073}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:22:13.705000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 99.87,
#            'AskSize': 109000.0,
#            'Bid': 99.78,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 99.83,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 29173769}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:22:13.958000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 102.35,
#            'AskSize': 0.0,
#            'Bid': 101.95,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 102.15,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 38067934}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T06:46:56.085000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 99.5,
#            'AskSize': 1651407.0,
#            'Bid': 0.0,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 99.5,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'NoMarket',
#            'PriceTypeBid': 'NoMarket'},
#  'Uic': 29291481}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:22:13.819000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 103.3,
#            'AskSize': 0.0,
#            'Bid': 102.8,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 103.05,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 33259536}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:23:13.517000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 94.8,
#            'AskSize': 0.0,
#            'Bid': 94.2,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 94.5,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 28486673}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:23:13.510000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 101.5,
#            'AskSize': 0.0,
#            'Bid': 101.0,
#            'BidSize': 60000.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 101.25,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 30982105}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:23:13.609000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 88.7,
#            'AskSize': 0.0,
#            'Bid': 88.1,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 88.4,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 27511968}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:23:13.441000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 96.05,
#            'AskSize': 20000000.0,
#            'Bid': 95.86,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 95.96,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 14603236}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:23:13.390000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 99.14,
#            'AskSize': 0.0,
#            'Bid': 99.04,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 99.09,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 32338155}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:23:13.434000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 98.72,
#            'AskSize': 0.0,
#            'Bid': 98.58,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 98.65,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 14601214}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:23:13.503000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 101.3,
#            'AskSize': 0.0,
#            'Bid': 100.5,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 100.9,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 30982101}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:23:13.455000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 83.45,
#            'AskSize': 0.0,
#            'Bid': 82.65,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 83.05,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 19770344}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:23:13.390000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 98.23,
#            'AskSize': 0.0,
#            'Bid': 98.05,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 98.14,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 29937695}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T06:30:00.120000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 63.75,
#            'AskSize': 0.0,
#            'Bid': 0.0,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 63.75,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'NoMarket',
#            'PriceTypeBid': 'NoMarket'},
#  'Uic': 32339007}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:23:13.554000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 0.0,
#            'AskSize': 0.0,
#            'Bid': 109.75,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 109.75,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 1269898}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:23:13.582000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 95.49,
#            'AskSize': 3000000.0,
#            'Bid': 94.89,
#            'BidSize': 3000000.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 95.19,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 39684714}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:23:13.517000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 100.16,
#            'AskSize': 0.0,
#            'Bid': 100.06,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 100.11,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 14596271}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:23:13.429000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 78.7,
#            'AskSize': 5000000.0,
#            'Bid': 78.15,
#            'BidSize': 5000000.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 78.43,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 14234274}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:23:13.634000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 102.9,
#            'AskSize': 0.0,
#            'Bid': 102.54,
#            'BidSize': 5000000.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 102.72,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 37978058}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:23:13.451000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 98.45,
#            'AskSize': 0.0,
#            'Bid': 97.65,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 98.05,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 30982103}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:23:13.475000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 102.55,
#            'AskSize': 0.0,
#            'Bid': 101.55,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 102.05,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 1177484}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:23:13.596000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 101.85,
#            'AskSize': 0.0,
#            'Bid': 100.85,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 101.35,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 9087434}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:23:13.471000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 99.32,
#            'AskSize': 0.0,
#            'Bid': 99.16,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 99.24,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 33259497}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:23:13.544000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 108.25,
#            'AskSize': 0.0,
#            'Bid': 106.25,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 107.25,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 1184883}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:23:13.524000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 97.65,
#            'AskSize': 0.0,
#            'Bid': 97.05,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 97.35,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 32407227}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:23:13.537000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 93.55,
#            'AskSize': 0.0,
#            'Bid': 92.95,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 93.25,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 28649813}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:23:13.663000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 88.4,
#            'AskSize': 0.0,
#            'Bid': 87.6,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 88.0,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 13986464}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:23:13.513000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 97.61,
#            'AskSize': 0.0,
#            'Bid': 97.39,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 97.5,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 14601213}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:18:04.006000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 90.27,
#            'AskSize': 2000000.0,
#            'Bid': 89.57,
#            'BidSize': 2000000.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 89.92,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 30032986}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:23:13.443000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 79.85,
#            'AskSize': 0.0,
#            'Bid': 79.25,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 79.55,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 17598747}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:23:13.525000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 104.7,
#            'AskSize': 0.0,
#            'Bid': 103.7,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 104.2,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 31995168}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:23:13.474000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 96.93,
#            'AskSize': 0.0,
#            'Bid': 96.68,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 96.81,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 36323470}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:23:13.427000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 78.95,
#            'AskSize': 0.0,
#            'Bid': 78.53,
#            'BidSize': 5000000.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 78.74,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 14231797}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:23:13.529000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 103.3,
#            'AskSize': 0.0,
#            'Bid': 102.8,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 103.05,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 36413429}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:23:13.574000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 108.4,
#            'AskSize': 0.0,
#            'Bid': 96.0,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 102.2,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 1067235}
# {'AssetType': 'Bond',
#  'LastUpdated': '0001-01-01T00:00:00.000000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'ErrorCode': 'None',
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'NoAccess',
#            'PriceTypeBid': 'NoAccess'},
#  'Uic': 1177487}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:23:13.495000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 102.55,
#            'AskSize': 0.0,
#            'Bid': 101.55,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 102.05,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 1177807}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:23:13.496000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 102.55,
#            'AskSize': 0.0,
#            'Bid': 101.55,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 102.05,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 1177832}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:23:13.542000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 103.2,
#            'AskSize': 0.0,
#            'Bid': 101.2,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 102.2,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 1177845}
# {'AssetType': 'Bond',
#  'LastUpdated': '0001-01-01T00:00:00.000000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'ErrorCode': 'None',
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'NoAccess',
#            'PriceTypeBid': 'NoAccess'},
#  'Uic': 1266556}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:23:13.550000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 99.85,
#            'AskSize': 0.0,
#            'Bid': 99.05,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 99.45,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 1266111}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:23:13.431000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 82.25,
#            'AskSize': 0.0,
#            'Bid': 81.72,
#            'BidSize': 5000000.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 81.99,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 28647095}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:23:13.646000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 90.94,
#            'AskSize': 0.0,
#            'Bid': 89.54,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 90.24,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 33259501}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:23:13.435000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 81.4,
#            'AskSize': 0.0,
#            'Bid': 80.8,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 81.1,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 13387321}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:23:13.449000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 84.65,
#            'AskSize': 0.0,
#            'Bid': 84.05,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 84.35,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 28649811}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:23:13.541000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 101.7,
#            'AskSize': 0.0,
#            'Bid': 101.1,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 101.4,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 1058543}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:23:13.564000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 102.7,
#            'AskSize': 0.0,
#            'Bid': 100.7,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 101.7,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 1066290}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:23:13.548000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 99.5,
#            'AskSize': 0.0,
#            'Bid': 98.5,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 99.0,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 1189457}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:23:13.571000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 102.45,
#            'AskSize': 0.0,
#            'Bid': 101.45,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 101.95,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 1067202}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:23:13.411000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 98.6,
#            'AskSize': 0.0,
#            'Bid': 97.8,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 98.2,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 1064932}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:23:13.458000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 93.85,
#            'AskSize': 0.0,
#            'Bid': 93.15,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 93.5,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 1359651}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:23:13.434000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 100.53,
#            'AskSize': 0.0,
#            'Bid': 100.33,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 100.43,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 34775342}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:23:13.439000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 75.71,
#            'AskSize': 0.0,
#            'Bid': 73.41,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 74.56,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 19716880}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:23:13.583000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 100.24,
#            'AskSize': 0.0,
#            'Bid': 100.04,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 100.14,
# ...
#  'LastUpdated': '0001-01-01T00:00:00.000000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'ErrorCode': 'None',
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'NoAccess',
#            'PriceTypeBid': 'NoAccess'},
#  'Uic': 36924824}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:32:13.042000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 77.3,
#            'AskSize': 0.0,
#            'Bid': 76.7,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 77.0,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 32304283}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:32:29.100000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 87.48,
#            'AskSize': 5000000.0,
#            'Bid': 87.26,
#            'BidSize': 5000000.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 87.37,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 21700606}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:27:34.029000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 97.43,
#            'AskSize': 5000000.0,
#            'Bid': 97.24,
#            'BidSize': 5000000.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 97.34,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 8819326}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T07:38:22.184000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 100.16,
#            'AskSize': 5000000.0,
#            'Bid': 100.01,
#            'BidSize': 5198214.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 100.09,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 1592298}
# {'AssetType': 'Bond',
#  'LastUpdated': '0001-01-01T00:00:00.000000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'ErrorCode': 'None',
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'NoAccess',
#            'PriceTypeBid': 'NoAccess'},
#  'Uic': 11716094}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:32:12.853000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 102.55,
#            'AskSize': 0.0,
#            'Bid': 101.55,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 102.05,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 1265946}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:32:12.974000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 100.6,
#            'AskSize': 0.0,
#            'Bid': 99.6,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 100.1,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 1266575}
# {'AssetType': 'Bond',
#  'LastUpdated': '0001-01-01T00:00:00.000000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'ErrorCode': 'None',
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'NoAccess',
#            'PriceTypeBid': 'NoAccess'},
#  'Uic': 1177512}
# {'AssetType': 'Bond',
#  'LastUpdated': '0001-01-01T00:00:00.000000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'ErrorCode': 'None',
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'NoAccess',
#            'PriceTypeBid': 'NoAccess'},
#  'Uic': 12055999}
# {'AssetType': 'Bond',
#  'LastUpdated': '0001-01-01T00:00:00.000000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'ErrorCode': 'None',
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'NoAccess',
#            'PriceTypeBid': 'NoAccess'},
#  'Uic': 12055994}
# {'AssetType': 'Bond',
#  'LastUpdated': '0001-01-01T00:00:00.000000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'ErrorCode': 'None',
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'NoAccess',
#            'PriceTypeBid': 'NoAccess'},
#  'Uic': 1272773}
# {'AssetType': 'Bond',
#  'LastUpdated': '0001-01-01T00:00:00.000000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'ErrorCode': 'None',
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'NoAccess',
#            'PriceTypeBid': 'NoAccess'},
#  'Uic': 9113445}
# {'AssetType': 'Bond',
#  'LastUpdated': '0001-01-01T00:00:00.000000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'ErrorCode': 'None',
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'NoAccess',
#            'PriceTypeBid': 'NoAccess'},
#  'Uic': 1272767}
# {'AssetType': 'Bond',
#  'LastUpdated': '0001-01-01T00:00:00.000000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'ErrorCode': 'None',
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'NoAccess',
#            'PriceTypeBid': 'NoAccess'},
#  'Uic': 1272768}
# {'AssetType': 'Bond',
#  'LastUpdated': '0001-01-01T00:00:00.000000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'ErrorCode': 'None',
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'NoAccess',
#            'PriceTypeBid': 'NoAccess'},
#  'Uic': 12055995}
# {'AssetType': 'Bond',
#  'LastUpdated': '0001-01-01T00:00:00.000000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'ErrorCode': 'None',
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'NoAccess',
#            'PriceTypeBid': 'NoAccess'},
#  'Uic': 32396356}
# {'AssetType': 'Bond',
#  'LastUpdated': '0001-01-01T00:00:00.000000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'ErrorCode': 'None',
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'NoAccess',
#            'PriceTypeBid': 'NoAccess'},
#  'Uic': 32395985}
# {'AssetType': 'Bond',
#  'LastUpdated': '0001-01-01T00:00:00.000000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'ErrorCode': 'None',
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'NoAccess',
#            'PriceTypeBid': 'NoAccess'},
#  'Uic': 1177549}
# {'AssetType': 'Bond',
#  'LastUpdated': '0001-01-01T00:00:00.000000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'ErrorCode': 'None',
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'NoAccess',
#            'PriceTypeBid': 'NoAccess'},
#  'Uic': 1268279}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:32:13.079000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 105.4,
#            'AskSize': 0.0,
#            'Bid': 104.4,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 104.9,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 12056023}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:32:13.074000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 105.25,
#            'AskSize': 0.0,
#            'Bid': 104.25,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 104.75,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 11716093}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:32:13.073000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 105.2,
#            'AskSize': 0.0,
#            'Bid': 104.2,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 104.7,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 11716092}
# {'AssetType': 'Bond',
#  'LastUpdated': '0001-01-01T00:00:00.000000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'ErrorCode': 'None',
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'NoAccess',
#            'PriceTypeBid': 'NoAccess'},
#  'Uic': 38984232}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:32:13.073000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 100.63,
#            'AskSize': 0.0,
#            'Bid': 100.33,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 100.48,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 11716080}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:32:13.039000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 101.31,
#            'AskSize': 0.0,
#            'Bid': 100.41,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 100.86,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 32302444}
# {'AssetType': 'Bond',
#  'LastUpdated': '0001-01-01T00:00:00.000000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'ErrorCode': 'None',
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'NoAccess',
#            'PriceTypeBid': 'NoAccess'},
#  'Uic': 23242091}
# {'AssetType': 'Bond',
#  'LastUpdated': '0001-01-01T00:00:00.000000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'ErrorCode': 'None',
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'NoAccess',
#            'PriceTypeBid': 'NoAccess'},
#  'Uic': 39429730}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:33:12.729000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 99.86,
#            'AskSize': 0.0,
#            'Bid': 99.76,
#            'BidSize': 0.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 99.81,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 28391086}
# {'AssetType': 'Bond',
#  'LastUpdated': '0001-01-01T00:00:00.000000Z',
#  'PriceSource': 'LUX_BONDS',
#  'Quote': {'Amount': 0,
#            'ErrorCode': 'None',
#            'PriceSource': 'LUX_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'NoAccess',
#            'PriceTypeBid': 'NoAccess'},
#  'Uic': 22874607}
# {'AssetType': 'Bond',
#  'LastUpdated': '0001-01-01T00:00:00.000000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'ErrorCode': 'None',
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'NoAccess',
#            'PriceTypeBid': 'NoAccess'},
#  'Uic': 1271691}
# {'AssetType': 'Bond',
#  'InstrumentPriceDetails': {'PriceFeedType': 'Consolidated'},
#  'LastUpdated': '2025-04-28T08:32:50.244000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'Ask': 94.22,
#            'AskSize': 5000000.0,
#            'Bid': 94.03,
#            'BidSize': 5000000.0,
#            'DelayedByMinutes': 15,
#            'ErrorCode': 'None',
#            'MarketState': 'Open',
#            'Mid': 94.13,
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'OldIndicative',
#            'PriceTypeBid': 'OldIndicative'},
#  'Uic': 21700603}
# {'AssetType': 'Bond',
#  'LastUpdated': '0001-01-01T00:00:00.000000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'ErrorCode': 'None',
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'NoAccess',
#            'PriceTypeBid': 'NoAccess'},
#  'Uic': 11716305}
# {'AssetType': 'Bond',
#  'LastUpdated': '0001-01-01T00:00:00.000000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'ErrorCode': 'None',
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'NoAccess',
#            'PriceTypeBid': 'NoAccess'},
#  'Uic': 33259516}
# {'AssetType': 'Bond',
#  'LastUpdated': '0001-01-01T00:00:00.000000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'ErrorCode': 'None',
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'NoAccess',
#            'PriceTypeBid': 'NoAccess'},
#  'Uic': 40331334}
# {'AssetType': 'Bond',
#  'LastUpdated': '0001-01-01T00:00:00.000000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'ErrorCode': 'None',
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'NoAccess',
#            'PriceTypeBid': 'NoAccess'},
#  'Uic': 33259476}
# {'AssetType': 'Bond',
#  'LastUpdated': '0001-01-01T00:00:00.000000Z',
#  'PriceSource': 'CSE_BONDS',
#  'Quote': {'Amount': 0,
#            'ErrorCode': 'None',
#            'PriceSource': 'CSE_BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'NoAccess',
#            'PriceTypeBid': 'NoAccess'},
#  'Uic': 12055979}
# {'AssetType': 'Bond',
#  'LastUpdated': '0001-01-01T00:00:00.000000Z',
#  'PriceSource': 'BONDS',
#  'Quote': {'Amount': 0,
#            'ErrorCode': 'None',
#            'PriceSource': 'BONDS',
#            'PriceSourceType': 'Firm',
#            'PriceTypeAsk': 'NoAccess',
#            'PriceTypeBid': 'NoAccess'},
#  'Uic': 41498377}
